# %%
import pandas as pd

# %%
pd.read_csv('TLE_Student_Performance_Data.csv')
# Out:
#    Student_ID  Gender Prior_Knowledge_TLE Teacher_Specialization  \
# 0        S001    Male                 Yes            Agriculture
# 1        S002  Female                 Yes        Industrial Arts
# 2        S003    Male                 Yes        Industrial Arts
# 3        S004    Male                  No        Industrial Arts
# 4        S005  Female                 Yes                    ICT
# 5        S006    Male                  No        Industrial Arts
# 6        S007    Male                  No            Agriculture
# 7        S008    Male                  No                Non-TLE
# 8        S009  Female                 Yes        Industrial Arts
# 9        S010    Male                  No                Tourism
# 10       S011    Male                 Yes        Industrial Arts
# 11       S012    Male                  No                Tourism
# 12       S013    Male                 Yes                Non-TLE
# ...

# %%
df = pd.read_csv('TLE_Student_Performance_Data.csv')

# %%
df.to_csv('My_output',index=False)

# %%
pd.read_csv('My_output')
# Out:
#    Student_ID  Gender Prior_Knowledge_TLE Teacher_Specialization  \
# 0        S001    Male                 Yes            Agriculture
# 1        S002  Female                 Yes        Industrial Arts
# 2        S003    Male                 Yes        Industrial Arts
# 3        S004    Male                  No        Industrial Arts
# 4        S005  Female                 Yes                    ICT
# 5        S006    Male                  No        Industrial Arts
# 6        S007    Male                  No            Agriculture
# 7        S008    Male                  No                Non-TLE
# 8        S009  Female                 Yes        Industrial Arts
# 9        S010    Male                  No                Tourism
# 10       S011    Male                 Yes        Industrial Arts
# 11       S012    Male                  No                Tourism
# 12       S013    Male                 Yes                Non-TLE
# ...

# %%
pd.read_excel('NSDB.xlsx',sheet_name='Sheet1')
# Out:
#    Research Title: "The Impact of TLE Teachers Handling Multiple Learning Areas on Grade 7 Students’ Performance: A Predictive System for Student Outcomes in Different Skill Areas"  \
# 0                                 By: Ernesto M. Paje
# 1                                                 NaN
# 2                                    TITLE OF ARTICLE
# 3                                                 NaN
# 4   1. Teacher’s Workload and its Efficacy in Clas...
# 5   2. Teacher’s Workload Intensification: A Quali...
# 6   3. Multitasking of Teachers in the Contemporar...
# 7   4. Teachers’ Workload Policy Its Impact on Phi...
# 8   5. Workload, Work Intensification and Time Pov...
# 9   6. Facilitating Learning and Academic Performa...
# 10           7. The Lived Experiences of TLE Teachers
# 11  8. TLE Observation and Evaluation System Handb...
# 12  9. A Review Study on Predictive Analytical Too...
# 13  10. A Systematic Literature Review of Student ...
# ...

# %%
df.to_excel('NSDB2.xlsx',sheet_name='Sheet1')

# %%
data = pd.read_html('https://www.fdic.gov/bank-failures/failed-bank-list')

# %%
data[0].head()
# Out:
#                                Bank Name          City         State   Cert  \
# 0                   Pulaski Savings Bank       Chicago      Illinois  28611
# 1     The First National Bank of Lindsay       Lindsay      Oklahoma   4134
# 2  Republic First Bank dba Republic Bank  Philadelphia  Pennsylvania  27332
# 3                          Citizens Bank      Sac City          Iowa   8758
# 4               Heartland Tri-State Bank       Elkhart        Kansas  25851
#
#                 Acquiring Institution      Closing Date  Fund  Sort ascending
# 0                     Millennium Bank  January 17, 2025                 10548
# 1  First Bank & Trust Co., Duncan, OK  October 18, 2024                 10547
# 2   Fulton Bank, National Association    April 26, 2024                 10546
# 3           Iowa Trust & Savings Bank  November 3, 2023                 10545
# 4              Dream First Bank, N.A.     July 28, 2023                 10544

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('my_table',engine)
# Out:
# 50

# %%
sqldf = pd.read_sql('my_table',con=engine)

# %%
sqldf
# Out:
#     index Student_ID  Gender Prior_Knowledge_TLE Teacher_Specialization  \
# 0       0       S001    Male                 Yes            Agriculture
# 1       1       S002  Female                 Yes        Industrial Arts
# 2       2       S003    Male                 Yes        Industrial Arts
# 3       3       S004    Male                  No        Industrial Arts
# 4       4       S005  Female                 Yes                    ICT
# 5       5       S006    Male                  No        Industrial Arts
# 6       6       S007    Male                  No            Agriculture
# 7       7       S008    Male                  No                Non-TLE
# 8       8       S009  Female                 Yes        Industrial Arts
# 9       9       S010    Male                  No                Tourism
# 10     10       S011    Male                 Yes        Industrial Arts
# 11     11       S012    Male                  No                Tourism
# ...
